# %%
# !pip install git+https://github.com/huggingface/transformers.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 82.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.9 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done

# %%
from transformers import pipeline

# %%
whisper = pipeline('automatic-speech-recognition', model = 'openai/whisper-medium', device = 0 )
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.99k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/3.06G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/3.69k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.20M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# Downloading (…)main/normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]

# %%
# !wget -O audio.mp3 http://www.moviesoundclips.net/movies1/harrypotterhalfbloodprince/no.mp3
# Out:
# --2023-08-26 05:27:24--  http://www.moviesoundclips.net/movies1/harrypotterhalfbloodprince/no.mp3
# Resolving www.moviesoundclips.net (www.moviesoundclips.net)... 198.54.115.219
# Connecting to www.moviesoundclips.net (www.moviesoundclips.net)|198.54.115.219|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45608 (45K) [audio/mpeg]
# Saving to: ‘audio.mp3’
#
# audio.mp3           100%[===================>]  44.54K   118KB/s    in 0.4s
#
# 2023-08-26 05:27:24 (118 KB/s) - ‘audio.mp3’ saved [45608/45608]

# %%
from IPython.display import Audio, display
display(Audio('audio.mp3', autoplay = True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text = whisper('audio.mp3')

# %%
text
# Out:
# {'text': " The answer's still no. Absolutely and unequivocally no."}
